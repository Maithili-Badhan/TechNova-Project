# %% [markdown]
# ## Dataset Download

# %%
# !pip install roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 606.6 kB/s eta 0:01:04
#     --------------------------------------- 0.5/38.8 MB 606.6 kB/s eta 0:01:04
#     --------------------------------------- 0.8/38.8 MB 551.3 kB/s eta 0:01:09
#     --------------------------------------- 0.8/38.8 MB 551.3 kB/s eta 0:01:09
#     --------------------------------------- 0.8/38.8 MB 551.3 kB/s eta 0:01:09
#    - -------------------------------------- 1.0/38.8 MB 534.2 kB/s eta 0:01:11
#    - -------------------------------------- 1.0/38.8 MB 534.2 kB/s eta 0:01:11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MOxvJwlnLCEKkCKAAzqW")
project = rf.workspace("hadplus").project("hadplus-illegal-billboard-detector")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hadplus-illegal-billboard-detector-1 in yolov8:: 100%|██████████| 690/690 [00:02<00:00, 339.68it/s]

# %% [markdown]
# ## Yolov8s Setup

# %%
# !pip install ultralytics opencv-python
# (Optional) OCR later: pip install paddleocr
# Out:
# ^C
# ...
#   Using cached ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached torch-2.8.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# ...
#   Using cached torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# ...
#   Using cached ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached ultralytics-8.3.179-py3-none-any.whl (1.0 MB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# ...
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/241.3 MB 511.4 kB/s eta 0:07:51
# ...

# %%
yolo detect train model=yolov8s.pt data=C:/Users/KIIT/TechNova-Project/hadplus-illegal-billboard-detector-1/data.yaml imgsz=640 epochs=50 batch=16 device=0
# Best weights -> runs/detect/train/weights/best.pt

# %%
yolo segment train model=yolov8s-seg.pt data=C:/Users/KIIT/TechNova-Project/hadplus-illegal-billboard-detector-1/data.yaml imgsz=640 epochs=50 batch=16 device=0
# Best weights -> runs/segment/train/weights/best.pt
